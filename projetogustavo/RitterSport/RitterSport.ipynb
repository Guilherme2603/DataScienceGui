# %%
! pip install pandas
! pip install openpyxl

# %% [markdown]
# # Lendo arquivo e limpando dados

# %%
import pandas as pd

# %%
ritter = pd.read_excel('RitterSport_set23.xlsx', sheet_name='Base_#').reset_index()
ritter.head(30)
# Out:
#     index                     Unnamed: 0              Unnamed: 1 Unnamed: 2  \
# 0       0                            NaN                     NaN        NaN
# 1       1                            NaN                     NaN       SEXO
# 2       2                            NaN                     NaN      Total
# 3       3                            NaN                     NaN        NaN
# 4       4  Q1: A cidade que você mora é?                  Total         200
# 5       5                            NaN                     NaN        NaN
# 6       6                            NaN                 Capital         92
# 7       7                            NaN    Região metropolitana         43
# 8       8                            NaN      Interior do estado         65
# 9       9                            NaN                     NaN        NaN
# 10     10                            NaN                     NaN        NaN
# ...

# %%
ritter.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21'],
#       dtype='object')

# %%
perguntas = ritter['Unnamed: 0'].dropna().reset_index()
perguntas.columns=['linha','pergunta']
print(type(perguntas))
perguntas
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #### verifica a linha em perguntas , salva linhas do df comparando duas colunas ate achar NaN pela SEGUNDA VEZ, gera df auxilixar com dados

# %%
for index,linha,pergunta in perguntas:
    print(linha)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Gustavo\OneDrive\Documentos\GitHub\DataScienceGui\projetogustavo\RitterSport\RitterSport.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Gustavo/OneDrive/Documentos/GitHub/DataScienceGui/projetogustavo/RitterSport/RitterSport.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> for index,linha,pergunta in perguntas:
#       <a href='vscode-notebook-cell:/c%3A/Users/Gustavo/OneDrive/Documentos/GitHub/DataScienceGui/projetogustavo/RitterSport/RitterSport.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a>     print(linha)
#
# ValueError: too many values to unpack (expected 3)
